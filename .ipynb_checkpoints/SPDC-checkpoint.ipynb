# %%
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import time
import MatrixProductFunctions as mp
import AuxiliaryFunctions as af
import os
import cmath
import math
from numba import njit
import matplotlib.animation as animation
# %matplotlib inline
from ipywidgets import IntProgress, HTML
from IPython.display import display
import pickle
import matplotlib.gridspec as gridspec
from datetime import datetime
from scipy.linalg import sqrtm
import opt_einsum as oe
import sys
from pympler import asizeof
import socket

# %%
os.chdir(af.get_computer_specific_folder())
folder_name = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
os.makedirs(folder_name, exist_ok=True)
os.chdir(folder_name)
print(f"Все файлы будут сохраняться в: {os.getcwd()}")
# Out:
# Все файлы будут сохраняться в: C:\Users\kaprn\Desktop\MPS_directory\TensorNetworks\2025-09-08_12-27-22

# %% [markdown]
# #### Наша задача промоделировать процесс вырожденного спонтанного параметрического рассеяния (DSPDC), гамильтониан этого процесса имеет следующий вид:
# $\hat{H} = H_o + H_{spdc} = \hbar w \hat{a}^{\dagger}\hat{a} + \dfrac{\hbar w}{2}\hat{b}^{\dagger}\hat{b} + i\hbar \chi^{(2)}(\hat{a}^{\dagger}\hat{b}\hat{b} - \hat{a}\hat{b}^{\dagger}\hat{b}^{\dagger})$
#
#
# $H_{spdc} = i\hbar \chi^{(2)}(\hat{a}^{\dagger}\hat{b}\hat{b} - \hat{a}\hat{b}^{\dagger}\hat{b}^{\dagger}) = -i\dfrac{\hbar \chi^{(2)}}{2\sqrt{2}}((\hat{x_a} + \dfrac{d}{dx_a})(\hat{x_b^2} + \dfrac{d^2}{dx_b^2} - \hat{1_b} - 2x_b\dfrac{d}{dx_b}) - (\hat{x_a} - \dfrac{d}{dx_a})(\hat{x_b^2} + \dfrac{d^2}{dx_b^2} + \hat{1_b} + 2x_b\dfrac{d}{dx_b})) = -i\dfrac{\hbar \chi^{(2)}}{2\sqrt{2}}(2\dfrac{d}{dx_a}(\hat{x_b^2} + \dfrac{d^2}{dx_b^2}) - 2\hat{x_a}(\hat{1_b} + 2x_b\dfrac{d}{dx_b})) $

# %% [markdown]
# #### Гамильтониан общей энергии системы не привносит интересной физики, поэтому рассматриваем только гамильтониан взаимодействия

# %% [markdown]
# $H_{spdc} = i\hbar \chi^{(2)}(\hat{a}^{\dagger}\hat{b}\hat{b} - \hat{a}\hat{b}^{\dagger}\hat{b}^{\dagger}) =$
#
# $-i\dfrac{\hbar \chi^{(2)}}{\sqrt{2}}(\dfrac{d}{dx_a}(\hat{x_b^2} + \dfrac{d^2}{dx_b^2}) - \hat{x_a}(\hat{1_b} + 2\hat{x}_b\dfrac{d}{dx_b}))$

# %% [markdown]
# #### Определение параметров

# %%
chi = 1 / 2
theta = 0.001

t_general = 0.9
steps_number = 900
delta_t = t_general / steps_number

x_bond1 = 30
x_bond2 = 10

x_left = 10 + 2 * 10 * np.sqrt(2)
x_bias = 10 * np.sqrt(2)
x_right = 15

n1 = 12
n2 = 13

step1 = (x_right + x_left)/2**n1 #x_bond1 / 2**(n1 - 1)
step2 = x_bond2 / 2**(n2 - 1)

n3 = 10
x_bond3 = 10
step3 = x_bond3 / 2**(n3 - 1)

eps = 1e-9

# sp2 = np.linspace(-x_bond2, x_bond2, 2**n2)
# step2 = sp2[1]-sp2[0]

sp1 = np.linspace(x_bias-x_left, x_bias+x_right, 2**n1)
step1_v1 = sp1[1]-sp1[0]

#initial_guess = ['approx', 1e-2, 100] 
initial_guess = ['adaptive', 1e-4, 100, 5, 5, 2, 80]

bond_limit = 5

sweep_number = 1

# %%
sp2 = np.linspace(-x_bond2, x_bond2, 2**n2)
step2_2 = sp2[1]-sp2[0]
step2, step2_2, step1, step1_v1
# Out:
# (0.0006103515625,
#  0.0006103701895199265,
#  0.009242026137531098,
#  0.0092423081903803)

# %%
with open('Parameters.txt', 'w') as file:
    file.write(f"t_general={t_general}\n")
    file.write(f"chi={chi}\n")
    file.write(f"delta_t={delta_t}\n")
    file.write(f"x_bond1={x_bond1}\n")
    file.write(f"x_bond2={x_bond2}\n")
    file.write(f"n1={n1}\n")
    file.write(f"n2={n2}\n")
    file.write(f"step1={step1}\n")
    file.write(f"step2={step2}\n")
    file.write(f"x_bias={x_bias}\n")
    file.write(f"steps_number={steps_number}\n")
    file.write(f"theta={theta}\n")
    file.write(f"eps={eps}\n")
    file.write(f"x_left={x_left}\n")
    file.write(f"step1_v1={step1_v1}\n")
    file.write(f"n3={n3}\n")
    file.write(f"x_bond3={x_bond3}\n")
    file.write(f"step3={step3}\n")    
    file.write(f"x_right={x_right}\n")
    file.write("Comment: I launch the script to get the results for article\n")
    file.write(f"initial_guess={initial_guess}\n")
    file.write(f"bond_limit={bond_limit}\n")
    file.write(f"sweep_number={sweep_number}\n")

# %% [markdown]
# ### Задаем гамильтониан SPDC

# %% [markdown]
# #### Первая и вторая часть MPO для когерентного состояния: $\dfrac{d}{dx_a}$ и $-\hat{x}_a$

# %%
coh_operator_one = mp.der_mpo(n1, step1_v1)
coh_operator_two = mp.mpo_mul_num(mp.x_mpo(n1, x_bias - x_left, step1_v1), -1)

# %% [markdown]
# #### Первая и вторая часть MPO для вакуумного состояния: $\hat{x_b^2} + \dfrac{d^2}{dx_b^2}$ и $\hat{1_b} + 2\hat{x}_b\dfrac{d}{dx_b}$

# %%
vac_operator_one = mp.mpo_sum(mp.mpo_multiplication(mp.x_mpo(n2, - x_bond2, step2), mp.x_mpo(n2, - x_bond2, step2)), mp.der2_mpo(n2, step2))
vac_operator_two = mp.mpo_sum(mp.one_mpo(n2), mp.mpo_mul_num(mp.mpo_multiplication(mp.x_mpo(n2, - x_bond2, step2), mp.der_mpo(n2, step2)), 2))

# %% [markdown]
# #### Склейка mpo для когернетного состояния и вакуумного состояния

# %%
first_part = coh_operator_one + vac_operator_one
second_part = coh_operator_two + vac_operator_two

# %% [markdown]
# #### Полный гамильтониан

# %%
common_operator = mp.mpo_mul_num(mp.mpo_sum(first_part, second_part), chi / (np.sqrt(2)))
full_hamiltonian = mp.mpo_mul_num(mp.mpo_sum(first_part, second_part), chi / (np.sqrt(2)*1j))

# %%
# with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/data_for_Egor/weak_pump/hamiltonian.pkl', 'wb') as f:
#     pickle.dump(full_hamiltonian, f)

# %% [markdown]
# #### Уравнение

# %% [markdown]
# $(1 + i\Delta t \hat{H})\psi_{t+1} = \psi_t$

# %% [markdown]
# #### Матрица

# %%
final_mpo = mp.mpo_sum(mp.one_mpo(n1 + n2), mp.mpo_mul_num(common_operator, delta_t))

# %% [markdown]
# #### Начальное состояние

# %%
initial_state_mps = mp.asym_gauss_mps(x_left, x_right, n1, 1) + mp.asym_gauss_mps(x_bond2, x_bond2, n2, 1)
plt.plot(np.arange(-(2**n2)/2, (2**n2)/2) * step2, mp.tensors_multiplication(initial_state_mps[n1:]))
plt.plot(np.linspace(-x_left+x_bias, x_bias+x_right, 2**n1), mp.tensors_multiplication(initial_state_mps[:n1]))
plt.xlabel("Квадратура X")
plt.ylabel(r"$\psi(X)$")
plt.grid(which = 'major', alpha = 0.6)
plt.grid(which = 'minor', alpha = 0.2)
plt.minorticks_on()
plt.show()

# %%
# with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/data_for_Egor/weak_pump/initial_state.pkl', 'wb') as f:
#     pickle.dump(initial_state_mps, f)

# %%
for i in initial_state_mps:
    print(i.shape)
# Out:
# (1, 2, 1)
# (1, 2, 1)
# (1, 2, 1)
# (1, 2, 1)
# (1, 2, 2)
# (2, 2, 3)
# (3, 2, 5)
# (5, 2, 7)
# (7, 2, 6)
# (6, 2, 5)
# (5, 2, 4)
# (4, 2, 3)
# (3, 2, 3)
# (3, 2, 2)
# (2, 2, 1)
# (1, 2, 2)
# (2, 2, 2)
# (2, 2, 4)
# (4, 2, 6)
# (6, 2, 6)
# (6, 2, 5)
# (5, 2, 4)
# (4, 2, 4)
# (4, 2, 3)
# (3, 2, 3)
# (3, 2, 3)
# (3, 2, 2)
# (2, 2, 2)
# (2, 2, 2)
# (2, 2, 1)

# %% [markdown]
# ### Количество тензоров в mps и mpo

# %%
len(final_mpo), len(initial_state_mps), len(mp.x_mps(n1 + n2))
# Out:
# (30, 30, 30)

# %% [markdown]
# ### Задаем гамильтониан светоделителя (для единоразового внесения потерь в моду сигнала)

# %% [markdown]
# $\hat{H}_{bs} = \dfrac{\theta}{2i}(\hat{1}_{pump}\hat{a}^{\dagger}_{sig}\hat{a}_{loss} - \hat{1}_{pump}\hat{a}_{sig}\hat{a}^{\dagger}_{loss}) = \dfrac{\theta}{2}\hat{1}_{pump}(\hat{q}_{sig}\hat{p}_{loss} - \hat{q}_{loss}\hat{p}_{sig}) = -i\dfrac{\theta}{2}\hat{1}_{pump}(\hat{q}_{sig}\hat{\dfrac{d}{dq}}_{loss} - \hat{q}_{loss}\hat{\dfrac{d}{dq}}_{sig})$

# %%
hamlt_1 = mp.x_mpo(n2, -x_bond2, step2) + mp.der_mpo(n3, step3)
hamlt_2 = mp.der_mpo(n2, step2) + mp.x_mpo(n3, -x_bond3, step3)

hamiltonian = mp.one_mpo(n1) + mp.mpo_sum(hamlt_1, mp.mpo_mul_num(hamlt_2, -1))
evolution_mpo = mp.mpo_sum(mp.one_mpo(n1 + n2 + n3), mp.mpo_mul_num(hamiltonian, theta/2))

# %% [markdown]
# ### Задаем состояние для моды потерь

# %%
vacuum_state_mps = mp.sym_gauss_mps(x_bond3, 1, n3)

# %% [markdown]
# ### Вычисление эволюции моды накачки и моды сигнала под действием гамильтониана SPDC

# %%
#set_of_solutions = mp.evolute(initial_state_mps, final_mpo, steps_number, mp.mp_solve, initial_guess=initial_guess, eps=eps, bond_limit=bond_limit, renormalize = False)

# %%
#ex_mpo = mp.MatrixProductOperator(final_mpo)
#ex_mps = mp.MatrixProductState(initial_state_mps)
#ex_guess = mp.MatrixProductState(initial_state_mps)

# %%
set_of_solutions2 = mp.evolute10(initial_state_mps, final_mpo, steps_number, mp.mp_solve10, initial_guess=initial_guess, eps=eps, sweep_number=sweep_number, bond_limit=bond_limit, renormalize=False, way='')

# %%
# ar1 = mp.tensors_multiplication(set_of_solutions[-1])
# ar2 = mp.tensors_multiplication(set_of_solutions2[-1])

# %%
array1 = ar1
array2 = ar2
cosine_similarity = np.dot(array1, array2) / (np.linalg.norm(array1) * np.linalg.norm(array2))

# %%
cosine_similarity
# Out:
# 0.7539861064713811

# %%
initial_state_mps_1 = mp.asym_gauss_mps(x_left, x_right, 10, 1) + mp.asym_gauss_mps(x_bond2, x_bond2, 10, 1)

# %%
initial_state_mps_2 = mp.asym_gauss_mps(x_left, x_right, 15, 1) + mp.asym_gauss_mps(x_bond2, x_bond2, 15, 1)

# %%
mp.compute_norm(initial_state_mps_1)*32, mp.compute_norm(initial_state_mps_2)
# Out:
# (117.69045548749115, 117.80190478246286)

# %%
with open('solutions.pkl', 'wb') as f:
    pickle.dump(set_of_solutions2, f)

# %%
with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/2025-09-08_11-42-48/solutions.pkl', 'rb') as f:
     set_of_solutions3 = pickle.load(f)

# %%
len(set_of_solutions3)
# Out:
# 451

# %% [markdown]
# ### Построение графика бонда в ходе эволюции

# %%
bonds = [mp.get_bond(solution) for solution in set_of_solutions2]
plt.figure(figsize=(9,5))
plt.grid(which = 'major', alpha = 0.4)
plt.grid(which = 'minor', alpha = 0.1)
plt.minorticks_on()
plt.xlabel("Шаг эволюции", fontsize=13)
plt.ylabel("Бонд", fontsize=13)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.plot(bonds)
plt.savefig("bond dimension")
plt.show()

# %% [markdown]
# ### Вычисление эволюции числа фотонов под действием гамильтониана SPDC

# %%
photon_number_dynamics = mp.calculate_photon_number_in_set_of_solutions(set_of_solutions2, n1, n2, x_left, x_bond2, step1_v1, step2, x_bias, solver=mp.calculate_photon_number3, step=20)
# Out:
#  32%|██████████████████████████▌                                                       | 11/34 [04:30<09:25, 24.61s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 photon_number_dynamics = mp.calculate_photon_number_in_set_of_solutions(set_of_solutions2, n1, n2, x_left, x_bond2, step1_v1, step2, x_bias, solver=mp.calculate_photon_number3, step=20)
#
# File ~\Desktop\MPS_directory\TensorNetworks\MatrixProductFunctions.py:1711, in calculate_photon_number_in_set_of_solutions(set_of_solutions, n1, n2, x_bond1, x_bond2, step1, step2, x_bias, solver, bound, step, chart)
#    1709 j += 1
#    1710 photon_number_in_mode1.append(np.round(solver(set_of_solutions[i-1], 0, n1, x_bias-x_bond1, step1), 3))
# -> 1711 photon_number_in_mode2.append(np.round(solver(set_of_solutions[i-1], 1, n2, -x_bond2, step2), 3))
#    1712 photon_number_common = list(map(add, photon_number_in_mode1, photon_number_in_mode2))
#    1714 times_container.append(time.time() - start_time)
#
# File ~\Desktop\MPS_directory\TensorNetworks\MatrixProductFunctions.py:1759, in calculate_photon_number3(mps, position, length, x0, step)
#    1757     first_state_step = np.einsum("abc, ibjk, ejf -> aieckf", state_part[-1], photon_number_op[-1],  np.conj(state_part[-1]), optimize=True)
#    1758     for i in range(1, len(state_part)):
# -> 1759         first_state_step = np.einsum("abcdef, gja, hjob, woc -> ghwdef", first_state_step, state_part[-i-1], photon_number_op[-i-1], np.conj(state_part[-i-1]), optimize=True)
#    1761 # Вычисление следа матрицы плотности
#    1762 if position == 0:
#
# File ~\miniconda3\envs\matrpr\Lib\site-packages\numpy\core\einsumfunc.py:1434, in einsum(out, optimize, *operands, **kwargs)
#    1431         kwargs["out"] = out
#    1433     # Do the contraction
# -> 1434     new_view = c_einsum(einsum_str, *tmp_operands, **kwargs)
#    1436 # Append new items and dereference what we can
#    1437 operands.append(new_view)
#
# KeyboardInterrupt:

# %%
with open('photon_dynamics.pkl', 'wb') as f:
    pickle.dump(photon_number_dynamics, f)

# %%
# with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/Data_for_article/alpha_20_comparison/alpha20_tn_adaptive_evolute_ph_dynamics.pkl', 'rb') as f:
#     photon_number_dynamics = pickle.load(f)

# %% [markdown]
# ### Построение графика эволюции числа фотонов

# %%
fig, ax1 = plt.subplots(figsize = (8,5))
plt.grid(alpha=0.4)
ax1.set_xlabel("Время, условные единицы", fontsize = 16)
ax1.set_ylabel("Число фотонов в моде", fontsize = 16)
line1, = ax1.plot(np.arange(len(photon_number_dynamics[0]))*0.001, np.array(photon_number_dynamics[0]), label = "Photons in pump mode (tensor networks)")
line2, = ax1.plot(np.arange(len(photon_number_dynamics[0]))*0.001, photon_number_dynamics[1], label = "Photons in signal mode (tensor networks)")
line3, = ax1.plot(np.arange(len(photon_number_dynamics[0]))*0.001, 2*np.array(photon_number_dynamics[0]) + np.array(photon_number_dynamics[1])-1.2, label = "Total energy of the system in the number of photons")
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
ax1.tick_params(axis='both', which='major', labelsize=14)
plt.savefig('photon_dynamics.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Вычисление матриц плотности для обеих мод для решения на конкретном шаге

# %%
n_step = 225
reddm1 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 0, n1, 0)
reddm2 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 1, n2, 0)
reddm1 = reddm1 / np.trace(reddm1)
reddm2 = reddm2 / np.trace(reddm2)
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (13,6))
im1 = ax1.imshow(np.real(reddm1))
im2 = ax2.imshow(np.real(reddm2))
plt.show()

# %% [markdown]
# ### Вычисление матриц плотности для обеих мод в ходе эволюции

# %%
# pump_matrices = []
# signal_matrices = []
# for i in tqdm(range(0, len(set_of_solutions), 20)):
#     pump_matrix = mp.find_reduced_density_matrix2(set_of_solutions[i], 0, n1, 4)
#     pump_matrices.append(pump_matrix/np.trace(pump_matrix))
#     signal_matrix = mp.find_reduced_density_matrix2(set_of_solutions[i], 1, n2, 2)
#     signal_matrices.append(signal_matrix/np.trace(signal_matrix))

# %% [markdown]
# ### Построение матриц плотности обеих мод на конкретном шаге

# %%
i = 37
cut_number = 150
signal_mode_center = 2048
pump_cut_number = 1024
cut_signal_ratio = cut_number/signal_mode_center
cut_pump_ratio = pump_cut_number/1024
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (13,6))
im1 = ax1.imshow(np.real(pump_matrices[i])[1024-pump_cut_number:1024, 1024-pump_cut_number:1024], extent = [(sp1[-1]-2*sp1[-1]*cut_pump_ratio), sp1[-1], sp1[-1], (sp1[-1]-2*sp1[-1]*cut_pump_ratio)])
im2 = ax2.imshow(np.real(signal_matrices[i])[signal_mode_center-cut_number:signal_mode_center+cut_number, signal_mode_center-cut_number:signal_mode_center+cut_number], extent = [sp2[0]*cut_signal_ratio, sp2[-1]*cut_signal_ratio, sp2[-1]*cut_signal_ratio, sp2[0]*cut_signal_ratio])
#plt.title("Матрица плотности сигнала, вычисленная двумя способами и представленная в непрерывном представлении")
#ax1.text(1.35, 1.27, f'Матрица плотности моды сигнала в ходе эволюции под дейсвтием гамильтониана SPDC, \n вычисленная двумя разными методами и представленная в непрерывном представлении', transform=ax1.transAxes, ha='center')
#ax1.text(0.5, 1.05, f'Матрица плотности моды сигнала, \n вычисленная в координатном представлении \n с помощью тензорных сетей', transform=ax1.transAxes, ha='center')
#ax1.text(0.1, 0.9, f't={num_iter}', color = 'white', transform=ax1.transAxes, ha='center')
#ax2.text(0.5, 1.05, f'Матрица плотности моды сигнала, \n вычисленная в Фоковском базисе \n и переведенная в координатное представление', transform=ax2.transAxes, ha='center')
ax2.text(-1.5, 1.03, f't={0.1*i/50}', color = 'black', transform=ax2.transAxes, fontsize = 14)
fig.colorbar(im1, ax=ax1, shrink=0.8)
fig.colorbar(im2, ax=ax2, shrink=0.8)
# ax1.set_xlabel('X-quadrature')
# ax1.set_ylabel('P-quadrature')
# ax2.set_xlabel('X-quadrature')
# ax2.set_ylabel('P-quadrature')
ax1.set_xlabel("X", fontsize = 14)
ax1.set_ylabel("X'", fontsize = 14)
ax2.set_xlabel("X", fontsize = 14)
ax2.set_ylabel("X'", fontsize = 14)
ax1.tick_params(axis='both', which='major', labelsize=14)
ax2.tick_params(axis='both', which='major', labelsize=14)
#plt.savefig('density_matrix_ttt_0.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Работа с потерями

# %% [markdown]
# ### Добавление одного шага потерь в конце эволюции SPDC

# %%
general_mps = set_of_solutions[-10] + vacuum_state_mps

# %% [markdown]
# ### Выполнение эволюции под действием потерь

# %%
solution_with_losses = mp.evolute(general_mps, evolution_mpo, 600, mp.mp_solve, initial_guess=['approx', 1e-4], eps=eps)

# %%
# with open('list_of_solutions_for_loss_-10.pkl', 'wb') as f:
#      pickle.dump(solution_with_losses, f)

# %% [markdown]
# ### Вычисление матриц плотности состояний до внесения потерь

# %%
dm_pump_before_loss = mp.find_reduced_density_matrix_for_3_modes(solution_with_losses[0], 0, n1, n2, n3, 0)
dm_signal_before_loss = mp.find_reduced_density_matrix_for_3_modes(solution_with_losses[0], 1, n2, n1, n3, 0)
dm_loss_before_loss = mp.find_reduced_density_matrix_for_3_modes(solution_with_losses[0], 2, n3, n1, n2, 0)
dm_pump_before_loss = dm_pump_before_loss #/np.trace(dm_pump_before_loss)
dm_signal_before_loss = dm_signal_before_loss #/np.trace(dm_signal_before_loss)
dm_loss_before_loss = dm_loss_before_loss #/np.trace(dm_loss_before_loss)

# %% [markdown]
# ### Вычисление матриц плотности состояний после внесения потерь

# %%
dm_pump_after_loss = mp.find_reduced_density_matrix_for_3_modes(solution_with_losses[-1], 0, n1, n2, n3, 0)
dm_signal_after_loss = mp.find_reduced_density_matrix_for_3_modes(solution_with_losses[-1], 1, n2, n1, n3, 0)
dm_loss_after_loss = mp.find_reduced_density_matrix_for_3_modes(solution_with_losses[-1], 2, n3, n1, n2, 0)
dm_pump_after_loss = dm_pump_after_loss #/np.trace(dm_pump_after_loss)
dm_signal_after_loss = dm_signal_after_loss #/np.trace(dm_signal_after_loss)
dm_loss_after_loss = dm_loss_after_loss #/np.trace(dm_loss_after_loss)

# %% [markdown]
# ### Мода накачки до и после внесения потерь

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
im1 = axes[0].imshow(np.real(dm_pump_before_loss))
im2 = axes[1].imshow(np.real(dm_pump_after_loss))
fig.colorbar(im1, ax=axes[0])
fig.colorbar(im2, ax=axes[1])
plt.show()

# %%
print("Количество фотонов в моде накачки до и после внесения потерь", mp.calculate_ph_num(dm_pump_before_loss, n1, x_bias-x_left, step1_v1)/np.trace(dm_pump_before_loss), mp.calculate_ph_num(dm_pump_after_loss, n1, x_bias-x_left, step1_v1)/np.trace(dm_pump_after_loss))

# %% [markdown]
# ### Матрица плотности моды сигнала до и после внесения потерь

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
im1 = axes[0].imshow(np.real(dm_signal_before_loss))
im2 = axes[1].imshow(np.real(dm_signal_after_loss))
fig.colorbar(im1, ax=axes[0])
fig.colorbar(im2, ax=axes[1])
plt.show()

# %%
print("Количество фотонов в моде сигнала до и после внесения потерь", mp.calculate_ph_num(dm_signal_before_loss, n2, -x_bond2, step2)/np.trace(dm_signal_before_loss), mp.calculate_ph_num(dm_signal_after_loss, n2, -x_bond2, step2)/np.trace(dm_signal_after_loss))

# %% [markdown]
# ### Матрица плотности моды потерь до и после внесения потерь

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
im1 = axes[0].imshow(np.real(dm_loss_before_loss))
im2 = axes[1].imshow(np.real(dm_loss_after_loss))
fig.colorbar(im1, ax=axes[0])
fig.colorbar(im2, ax=axes[1])
plt.show()

# %%
print("Число фотонов в моде потерь до и после внесения потерь", mp.calculate_ph_num(dm_loss_before_loss, n3, -x_bond3, step3)/np.trace(dm_loss_before_loss), mp.calculate_ph_num(dm_loss_after_loss, n3, -x_bond3, step3)/np.trace(dm_loss_after_loss))

# %%
print("Полное число фотонов до внесения потерь", mp.calculate_ph_num(dm_pump_before_loss, n1, x_bias-x_left, step1_v1)/np.trace(dm_pump_before_loss) + mp.calculate_ph_num(dm_signal_before_loss, n2, -x_bond2, step2)/np.trace(dm_signal_before_loss) + mp.calculate_ph_num(dm_loss_before_loss, n3, -x_bond3, step3)/np.trace(dm_loss_before_loss))

# %%
print("Полное число фотонов после внесения потерь", mp.calculate_ph_num(dm_pump_after_loss, n1, x_bias-x_left, step1_v1)/np.trace(dm_pump_after_loss) + mp.calculate_ph_num(dm_signal_after_loss, n2, -x_bond2, step2)/np.trace(dm_signal_after_loss) + mp.calculate_ph_num(dm_loss_after_loss, n3, -x_bond3, step3)/np.trace(dm_loss_after_loss))

# %% [markdown]
# ### Вычисление динамики фотонов в модах в ходе внесения потерь

# %%
pump_stat = []
signal_stat = []
loss_stat = []
for i in tqdm(range(0,len(solution_with_losses),50)):
    dm_pump_before_loss = mp.find_reduced_density_matrix_for_3_modes(solution_with_losses[i], 0, n1, n2, n3, 0)
    dm_signal_before_loss = mp.find_reduced_density_matrix_for_3_modes(solution_with_losses[i], 1, n2, n1, n3, 0)
    dm_loss_before_loss = mp.find_reduced_density_matrix_for_3_modes(solution_with_losses[i], 2, n3, n1, n2, 0)
    pump_stat.append(mp.calculate_ph_num(dm_pump_before_loss, n1, x_bias-x_left, step1_v1)/np.trace(dm_pump_before_loss))
    signal_stat.append(mp.calculate_ph_num(dm_signal_before_loss, n2, -x_bond2, step2)/np.trace(dm_signal_before_loss))
    loss_stat.append(mp.calculate_ph_num(dm_loss_before_loss, n3, -x_bond3, step3)/np.trace(dm_loss_before_loss))

# %%
plt.plot(np.array(pump_stat)-np.ones(len(pump_stat))*pump_stat[0])
plt.plot(np.array(signal_stat)-np.ones(len(signal_stat))*signal_stat[0])
plt.plot(np.array(loss_stat)-np.ones(len(loss_stat))*loss_stat[0])
plt.plot(np.array(pump_stat)-np.ones(len(pump_stat))*pump_stat[0] + np.array(signal_stat)-np.ones(len(signal_stat))*signal_stat[0] + np.array(loss_stat)-np.ones(len(loss_stat))*loss_stat[0])
plt.scatter(np.arange(len(signal_stat)), signal_stat[0]*(np.cos(25*theta*np.arange(len(signal_stat))))**2 - signal_stat[0]*np.ones(len(signal_stat)))
plt.scatter(np.arange(len(signal_stat)), signal_stat[0]*(np.sin(25*theta*np.arange(len(signal_stat))))**2)
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## Код для генерации гифок

# %% [markdown]
# #### Создание папки для картинок

# %%
# output_folder = 'C:\Users\kaprn\Desktop\MPS_directory\TensorNetworks\Tests_of_spdc\Test_with_different_times'
# os.makedirs(output_folder, exist_ok=True)

# %%
shorten_list_for_matrices = []
saving_step = len(set_of_solutions)//50
for i in range(0, len(set_of_solutions), saving_step):
    shorten_list_for_matrices.append(set_of_solutions[i])

# %%
print("Количество картинок в гифке", len(shorten_list_for_matrices))

# %% [markdown]
# ### Функция генерации гифки по эволюции матриц плотности мод

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

extent1 = [-x_left + x_bias, x_right + x_bias, x_right + x_bias, -x_left + x_bias]
extent2 = [-(2**n2)/2 * step2, (2**n2)/2 * step2, (2**n2)/2 * step2, -(2**n2)/2 * step2]

first_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[0], 0, n1)
second_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[0], 1, n2)
first_matrix = first_matrix / np.trace(first_matrix)
second_matrix = second_matrix / np.trace(second_matrix)

im1 = axes[0].imshow(first_matrix, cmap='viridis', extent = extent1)
axes[0].set_title('Evolution of a coh state (pump)')
cbar1 = fig.colorbar(im1, ax=axes[0])
    
im2 = axes[1].imshow(second_matrix, cmap='viridis', extent = extent2)
axes[1].set_title('Evolution of a vac state (signal)')
cbar2 = fig.colorbar(im2, ax=axes[1])
count = 0

cohn = mp.calculate_ph_num(first_matrix, n1, x_bias - x_left, step1_v1)
vacn = mp.calculate_ph_num(second_matrix, n2, -x_bond2, step2)

text1 = axes[0].text(0.5, 1.25, f'Number of photons in coherent state {np.round(cohn, 1)}', transform=axes[0].transAxes, ha='center')
text11 = axes[0].text(0.5, 1.15, f'Grid {2**n1}, x {2**n1}', transform=axes[0].transAxes, ha='center')
text2 = axes[1].text(0.5, 1.25, f'Number of photons in vacuum state {np.round(vacn, 1)}', transform=axes[1].transAxes, ha='center')
text22 = axes[1].text(0.5, 1.15, f'Grid {2**n2}, x {2**n2}', transform=axes[1].transAxes, ha='center')
text3 = axes[0].text(1.3, 1.3, f'sum {np.round(np.round(2 * np.round(cohn, 1), 1) + np.round(vacn, 1), 1)}', transform=axes[0].transAxes, ha='center')

f = IntProgress(min = 0, max = len(shorten_list_for_matrices))
percentage = HTML(value='0%')

def update(num):
    global n1, n2, count, x_bond1, x_bond2, x_bias, step1, step2, delta_t, step1_v1, x_left, x_right

    length = len(shorten_list_for_matrices)
    first_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[num], 0, n1)
    second_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[num], 1, n2)
    first_matrix = first_matrix / np.trace(first_matrix)
    second_matrix = second_matrix / np.trace(second_matrix)
    
    cohn = mp.calculate_ph_num(first_matrix, n1, x_bias - x_left, step1_v1)
    vacn = mp.calculate_ph_num(second_matrix, n2, -x_bond2, step2)
    
    im1.set_data(first_matrix)
    im2.set_data(second_matrix)
    
    im1.set_clim(vmin=np.min(first_matrix), vmax=np.max(first_matrix))
    im2.set_clim(vmin=np.min(second_matrix), vmax=np.max(second_matrix))
    
    text1.set_text(f'Number of photons in coherent state {np.round(cohn, 1)}')
    text2.set_text(f'Number of photons in vacuum state {np.round(vacn, 1)}')
    text11.set_text(f'Grid {2**n1}, x {2**n1}')
    text22.set_text(f'Grid {2**n2}, x {2**n2}')
    text3.set_text(f'sum {np.round(np.round(2 * np.round(cohn, 1), 1) + np.round(vacn, 1), 1)}')
    
    #plt.text(0.5, 1, f'Time {np.round(delta_t * count, 4)}', transform=fig.transFigure, ha='center')
    #plt.text(0.5, 1.1, f'Number of photons in coherent state {np.round(cohn, 1)}, number of photons in vacuum state {np.round(vacn, 1)}', transform=fig.transFigure, ha='center')
    #plt.text(0.5, 1.05, f'sum {np.round(np.round(2 * np.round(cohn, 1), 1) + np.round(vacn, 1), 1)}', transform=fig.transFigure, ha='center')
    count += 1
    f.value += 1
    percentage.value = f'{int((f.value / length) * 100)}%'  # обновляем процент выполнения
    return im1, im2


ani = animation.FuncAnimation(fig, update, frames=len(shorten_list_for_matrices), interval=250, blit=True)

# %%
# f = IntProgress(min = 0, max = len(shorten_list_for_matrices))
# display(f)
# percentage = HTML(value='0%')
# display(percentage)

# ani.save('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/Test_with_different_times/Test_with_amplitude_as_in_article.gif', writer='pillow', fps=4)

# %% [markdown]
# ### Создание гифки с эволюцией функции Вигнера мод

# %%
shorten_list_for_matrices = []
saving_step = len(set_of_solutions)//50
for i in range(0, len(set_of_solutions), saving_step):
    shorten_list_for_matrices.append(set_of_solutions[i])

# %%
print("Количество картинок в гифке", len(shorten_list_for_matrices))

# %%
#fig, axes = plt.subplots(1, 2, figsize=(15, 8))
fig = plt.figure(figsize=(15, 10))
gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])

nq1_red = 1
np1_red = 1
nq2_red = 1
np2_red = 1

q1 = np.linspace(x_bias-x_left+5, x_bias+x_right-5, 2**(n1-nq1_red))
p1 = np.linspace(-5, 5, 2**(n1-np1_red))

q2 = np.linspace(-5, 5, 2**(n2-nq2_red))
p2 = np.linspace(-20, 20, 2**(n2-np2_red))

extent1 = [q1[0], q1[-1], p1[0], p1[-1]]
extent2 = [q2[0], q2[-1], p2[0], p2[-1]]

first_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[0], 0, n1)
second_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[0], 1, n2)
first_matrix = first_matrix / np.trace(first_matrix)
second_matrix = second_matrix / np.trace(second_matrix)

# im1 = axes[0].imshow(mp.wigner_function4(first_matrix, x_bias-x_left, x_bias+x_right, q1, p1, 1).T, cmap='viridis', extent = extent1)
# axes[0].set_xlabel('X-quadrature')
# axes[0].set_ylabel('P-quadrature')
# cbar1 = fig.colorbar(im1, ax=axes[0])

ax0 = fig.add_subplot(gs[0])
im0 = ax0.imshow(mp.wigner_function4(first_matrix, x_bias-x_left, x_bias+x_right, q1, p1, 1).T, cmap='viridis', extent = extent1)
ax0.set_xlabel('X-quadrature')
ax0.set_ylabel('P-quadrature')
cbar0 = fig.colorbar(im0, ax=ax0)
    
# im2 = axes[1].imshow(mp.wigner_function4(second_matrix, -x_bond2, x_bond2, q2, p2, 1).T, cmap='viridis', extent = extent2)
# axes[1].set_xlabel('X-quadrature')
# axes[1].set_ylabel('P-quadrature')
# cbar2 = fig.colorbar(im2, ax=axes[1])

ax1 = fig.add_subplot(gs[1])
im1 = ax1.imshow(mp.wigner_function4(second_matrix, -x_bond2, x_bond2, q2, p2, 1).T, cmap='viridis', extent = extent2)
ax1.set_xlabel('X-quadrature')
ax1.set_ylabel('P-quadrature')
cbar1 = fig.colorbar(im1, ax=ax1)

cohn = mp.calculate_ph_num(first_matrix, n1, x_bias- x_left, step1_v1)
vacn = mp.calculate_ph_num(second_matrix, n2, -x_bond2, step2)

text = fig.text(0.5, 0.95, f'Time: {0}', ha='center', fontsize=16)
#axes[0].set_title(f'Evolution of the pump state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
ax0.set_title(f'Evolution of the pump state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
#axes[1].set_title(f'Evolution of the signal state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')
ax1.set_title(f'Evolution of the signal state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')

f = IntProgress(min = 0, max = len(shorten_list_for_matrices))
percentage = HTML(value='0%')

count = 0

def update(num):
    global n1, n2, count, x1, x2, p1, p2, h, p_spep, x_right, x_left, step1_v1
    global x_bond1, x_bond2, x_bias, step1, step2, ph_num1, ph_num2, ph_num3, delta_t
    length = len(shorten_list_for_matrices)
    
    first_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[num], 0, n1)
    second_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[num], 1, n2)
    
    first_matrix = first_matrix / np.trace(first_matrix)
    second_matrix = second_matrix / np.trace(second_matrix)
    
    cohn = mp.calculate_ph_num(first_matrix, n1, x_bias-x_left, step1_v1)
    vacn = mp.calculate_ph_num(second_matrix, n2, -x_bond2, step2)
    
    wg1 = mp.wigner_function4(first_matrix, x_bias-x_left, x_bias+x_right, q1, p1, 1).T
    wg2 = mp.wigner_function4(second_matrix, -x_bond2, x_bond2, q2, p2, 1).T

    im0.set_data(wg1)
    im1.set_data(wg2)
    fig.canvas.draw_idle()  # Обновление отображения
    
    im0.set_clim(vmin=np.min(wg1), vmax=np.max(wg1))
    im1.set_clim(vmin=np.min(wg2), vmax=np.max(wg2))
    
    #axes[0].set_title(f'Evolution of the pump state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
    ax0.set_title(f'Evolution of the pump state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
    #axes[1].set_title(f'Evolution of the signal state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')
    ax1.set_title(f'Evolution of the signal state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')
    
    text.set_text(f'Time: {np.round(count*delta_t, 2)}')
    count += 1
    f.value += 1
    percentage.value = f'{int((f.value / length) * 100)}%'  # обновляем процент выполнения
    return im0, im1

ani = animation.FuncAnimation(fig, update, frames=len(shorten_list_for_matrices), interval=250, blit=True)
plt.show()

# %%
f = IntProgress(min = 0, max = len(shorten_list_for_matrices))
display(f)
percentage = HTML(value='0%')
display(percentage)

ani.save('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/New_test_with_quality/Wigner_function_for_full_process4.gif', writer='pillow', fps=4)

# %% [markdown]
# ### Вычисление эволюции функции Вигнера моды сигнала и моды потерь в ходе внесения потерь

# %% [markdown]
# #### Загружаем сохраненную информацию из памяти

# %%
with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/New_test_with_quality/list_of_solutions_for_loss_-25.pkl', 'rb') as f:
    solutions_with_losses = pickle.load(f)

# %%
shorten_list_for_matrices = []
saving_step = len(solutions_with_losses)//50
for i in range(0, len(solutions_with_losses), saving_step):
    shorten_list_for_matrices.append(solutions_with_losses[i])

# %%
print("Количество картинок в гифке", len(shorten_list_for_matrices))

# %%
#fig, axes = plt.subplots(1, 2, figsize=(15, 8))
fig = plt.figure(figsize=(15, 12))
gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])

nq1_red = 1
np1_red = 1
nq2_red = 2
np2_red = 2

q1 = np.linspace(-2, 2, 2**(n1-nq1_red))
p1 = np.linspace(-7, 7, 2**(n1-np1_red))

q2 = np.linspace(-5, 5, 2**(n2-nq2_red))
p2 = np.linspace(-15, 15, 2**(n2-np2_red))

extent1 = [q1[0], q1[-1], p1[0], p1[-1]]
extent2 = [q2[0], q2[-1], p2[0], p2[-1]]

first_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[0], 1, n2, n1, n3, 0)
second_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[0], 2, n3, n1, n2, 0)

# first_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[0], 0, n1)
# second_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[0], 1, n2)
first_matrix = first_matrix / np.trace(first_matrix)
second_matrix = second_matrix / np.trace(second_matrix)

# im1 = axes[0].imshow(mp.wigner_function4(first_matrix, x_bias-x_left, x_bias+x_right, q1, p1, 1).T, cmap='viridis', extent = extent1)
# axes[0].set_xlabel('X-quadrature')
# axes[0].set_ylabel('P-quadrature')
# cbar1 = fig.colorbar(im1, ax=axes[0])

ax0 = fig.add_subplot(gs[0])
im0 = ax0.imshow(mp.wigner_function4(first_matrix, -x_bond2, x_bond2, q1, p1, 1).T, cmap='viridis', extent = extent1)
ax0.set_xlabel('X-quadrature')
ax0.set_ylabel('P-quadrature')
cbar1 = fig.colorbar(im0, ax=ax0)
    
# im2 = axes[1].imshow(mp.wigner_function4(second_matrix, -x_bond2, x_bond2, q2, p2, 1).T, cmap='viridis', extent = extent2)
# axes[1].set_xlabel('X-quadrature')
# axes[1].set_ylabel('P-quadrature')
# cbar2 = fig.colorbar(im2, ax=axes[1])

ax1 = fig.add_subplot(gs[1])
im1 = ax1.imshow(mp.wigner_function4(second_matrix, -x_bond3, x_bond3, q2, p2, 1).T, cmap='viridis', extent = extent2)
ax1.set_xlabel('X-quadrature')
ax1.set_ylabel('P-quadrature')
cbar2 = fig.colorbar(im1, ax=ax1)

cohn = mp.calculate_ph_num(first_matrix, n2, -x_bond2, step2)
vacn = mp.calculate_ph_num(second_matrix, n3, -x_bond3, step3)

text = fig.text(0.5, 0.95, f'Time: {0}', ha='center', fontsize=16)
#axes[0].set_title(f'Evolution of the pump state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
ax0.set_title(f'Evolution of the signal state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
#axes[1].set_title(f'Evolution of the signal state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')
ax1.set_title(f'Evolution of the loss state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')

f = IntProgress(min = 0, max = len(shorten_list_for_matrices))
percentage = HTML(value='0%')

count = 0

def update(num):
    global n1, n2, count, x1, x2, p1, p2, h, p_spep, x_right, x_left, step1_v1
    global x_bond1, x_bond2, x_bias, step1, step2, step3, ph_num1, ph_num2, ph_num3, delta_t
    length = len(shorten_list_for_matrices)
    
    # first_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[num], 0, n1)
    # second_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[num], 1, n2)
    first_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[num], 1, n2, n1, n3, 0)
    second_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[num], 2, n3, n1, n2, 0)
    
    first_matrix = first_matrix / np.trace(first_matrix)
    second_matrix = second_matrix / np.trace(second_matrix)
    
    cohn = mp.calculate_ph_num(first_matrix, n2, -x_bond2, step2)
    vacn = mp.calculate_ph_num(second_matrix, n3, -x_bond3, step3)
    
    wg1 = mp.wigner_function4(first_matrix, -x_bond2, x_bond2, q1, p1, 1).T
    wg2 = mp.wigner_function4(second_matrix, -x_bond3, x_bond3, q2, p2, 1).T

    im0.set_data(wg1)
    im1.set_data(wg2)
    fig.canvas.draw_idle()  # Обновление отображения
    
    im0.set_clim(vmin=np.min(wg1), vmax=np.max(wg1))
    im1.set_clim(vmin=np.min(wg2), vmax=np.max(wg2))
    
    #axes[0].set_title(f'Evolution of the pump state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
    ax0.set_title(f'Evolution of the signal state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
    #axes[1].set_title(f'Evolution of the signal state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')
    ax1.set_title(f'Evolution of the loss state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')
    
    text.set_text(f'Time: {np.round(count*delta_t, 2)}')
    count += 1
    f.value += 1
    percentage.value = f'{int((f.value / length) * 100)}%'  # обновляем процент выполнения
    return im0, im1

ani = animation.FuncAnimation(fig, update, frames=len(shorten_list_for_matrices), interval=250, blit=True)
plt.show()

# %%
f = IntProgress(min = 0, max = len(shorten_list_for_matrices))
display(f)
percentage = HTML(value='0%')
display(percentage)

ani.save('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/New_test_with_quality/Wigner_function_for_loss_process_-25_№4.gif', writer='pillow', fps=4)

# %%
# with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/New_test_with_quality/list_of_solutions_for_loss_-25.pkl', 'rb') as f:
#     solutions_with_losses = pickle.load(f)

# %%
shorten_list_for_matrices = []
saving_step = len(solutions_with_losses)//50
for i in range(0, len(solutions_with_losses), saving_step):
    shorten_list_for_matrices.append(solutions_with_losses[i])

# %%
print("Количество картинок в гифке", len(shorten_list_for_matrices))

# %%
#fig, axes = plt.subplots(1, 2, figsize=(15, 8))
fig = plt.figure(figsize=(15, 12))
gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])

nq1_red = 0
np1_red = 0
nq2_red = 2
np2_red = 2

q1 = np.linspace(-4, 4, 2**(n1-nq1_red))
p1 = np.linspace(-5, 5, 2**(n1-np1_red))

q2 = np.linspace(-5, 5, 2**(n2-nq2_red))
p2 = np.linspace(-15, 15, 2**(n2-np2_red))

extent1 = [q1[0], q1[-1], p1[0], p1[-1]]
extent2 = [q2[0], q2[-1], p2[0], p2[-1]]

first_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[0], 1, n2, n1, n3, 0)
second_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[0], 2, n3, n1, n2, 0)

# first_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[0], 0, n1)
# second_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[0], 1, n2)
first_matrix = first_matrix / np.trace(first_matrix)
second_matrix = second_matrix / np.trace(second_matrix)

# im1 = axes[0].imshow(mp.wigner_function4(first_matrix, x_bias-x_left, x_bias+x_right, q1, p1, 1).T, cmap='viridis', extent = extent1)
# axes[0].set_xlabel('X-quadrature')
# axes[0].set_ylabel('P-quadrature')
# cbar1 = fig.colorbar(im1, ax=axes[0])

ax0 = fig.add_subplot(gs[0])
im0 = ax0.imshow(mp.wigner_function4(first_matrix, -x_bond2, x_bond2, q1, p1, 1).T, cmap='viridis', extent = extent1)
ax0.set_xlabel('X-quadrature')
ax0.set_ylabel('P-quadrature')
cbar1 = fig.colorbar(im0, ax=ax0)
    
# im2 = axes[1].imshow(mp.wigner_function4(second_matrix, -x_bond2, x_bond2, q2, p2, 1).T, cmap='viridis', extent = extent2)
# axes[1].set_xlabel('X-quadrature')
# axes[1].set_ylabel('P-quadrature')
# cbar2 = fig.colorbar(im2, ax=axes[1])

ax1 = fig.add_subplot(gs[1])
im1 = ax1.imshow(mp.wigner_function4(second_matrix, -x_bond3, x_bond3, q2, p2, 1).T, cmap='viridis', extent = extent2)
ax1.set_xlabel('X-quadrature')
ax1.set_ylabel('P-quadrature')
cbar2 = fig.colorbar(im1, ax=ax1)

cohn = mp.calculate_ph_num(first_matrix, n2, -x_bond2, step2)
vacn = mp.calculate_ph_num(second_matrix, n3, -x_bond3, step3)

text = fig.text(0.5, 0.95, f'Time: {0}', ha='center', fontsize=16)
#axes[0].set_title(f'Evolution of the pump state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
ax0.set_title(f'Evolution of the signal state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
#axes[1].set_title(f'Evolution of the signal state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')
ax1.set_title(f'Evolution of the loss state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')

f = IntProgress(min = 0, max = len(shorten_list_for_matrices))
percentage = HTML(value='0%')

count = 0

def update(num):
    global n1, n2, count, x1, x2, p1, p2, h, p_spep, x_right, x_left, step1_v1
    global x_bond1, x_bond2, x_bias, step1, step2, step3, ph_num1, ph_num2, ph_num3, delta_t
    length = len(shorten_list_for_matrices)
    
    # first_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[num], 0, n1)
    # second_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[num], 1, n2)
    first_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[num], 1, n2, n1, n3, 0)
    second_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[num], 2, n3, n1, n2, 0)
    
    first_matrix = first_matrix / np.trace(first_matrix)
    second_matrix = second_matrix / np.trace(second_matrix)
    
    cohn = mp.calculate_ph_num(first_matrix, n2, -x_bond2, step2)
    vacn = mp.calculate_ph_num(second_matrix, n3, -x_bond3, step3)
    
    wg1 = mp.wigner_function4(first_matrix, -x_bond2, x_bond2, q1, p1, 1).T
    wg2 = mp.wigner_function4(second_matrix, -x_bond3, x_bond3, q2, p2, 1).T

    im0.set_data(wg1)
    im1.set_data(wg2)
    fig.canvas.draw_idle()  # Обновление отображения
    
    im0.set_clim(vmin=np.min(wg1), vmax=np.max(wg1))
    im1.set_clim(vmin=np.min(wg2), vmax=np.max(wg2))
    
    #axes[0].set_title(f'Evolution of the pump state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
    ax0.set_title(f'Evolution of the signal state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
    #axes[1].set_title(f'Evolution of the signal state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')
    ax1.set_title(f'Evolution of the loss state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')
    
    text.set_text(f'Time: {np.round(count*delta_t, 2)}')
    count += 1
    f.value += 1
    percentage.value = f'{int((f.value / length) * 100)}%'  # обновляем процент выполнения
    return im0, im1

ani = animation.FuncAnimation(fig, update, frames=len(shorten_list_for_matrices), interval=250, blit=True)
plt.show()

# %%
f = IntProgress(min = 0, max = len(shorten_list_for_matrices))
display(f)
percentage = HTML(value='0%')
display(percentage)

ani.save('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/New_test_with_quality/Wigner_function_for_loss_process_-25_№3.gif', writer='pillow', fps=4)

# %%
with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/New_test_with_quality/list_of_solutions_for_loss_-10.pkl', 'rb') as f:
    solutions_with_losses = pickle.load(f)

# %%
shorten_list_for_matrices = []
saving_step = len(solutions_with_losses)//50
for i in range(0, len(solutions_with_losses), saving_step):
    shorten_list_for_matrices.append(solutions_with_losses[i])

# %%
print("Количество картинок в гифке", len(shorten_list_for_matrices))

# %%
#fig, axes = plt.subplots(1, 2, figsize=(15, 8))
fig = plt.figure(figsize=(15, 12))
gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])

nq1_red = 2
np1_red = 2
nq2_red = 3
np2_red = 3

q1 = np.linspace(-4, 4, 2**(n1-nq1_red))
p1 = np.linspace(-15, 15, 2**(n1-np1_red))

q2 = np.linspace(-5, 5, 2**(n2-nq2_red))
p2 = np.linspace(-20, 20, 2**(n2-np2_red))

extent1 = [q1[0], q1[-1], p1[0], p1[-1]]
extent2 = [q2[0], q2[-1], p2[0], p2[-1]]

first_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[0], 1, n2, n1, n3, 0)
second_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[0], 2, n3, n1, n2, 0)

# first_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[0], 0, n1)
# second_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[0], 1, n2)
first_matrix = first_matrix / np.trace(first_matrix)
second_matrix = second_matrix / np.trace(second_matrix)

# im1 = axes[0].imshow(mp.wigner_function4(first_matrix, x_bias-x_left, x_bias+x_right, q1, p1, 1).T, cmap='viridis', extent = extent1)
# axes[0].set_xlabel('X-quadrature')
# axes[0].set_ylabel('P-quadrature')
# cbar1 = fig.colorbar(im1, ax=axes[0])

ax0 = fig.add_subplot(gs[0])
im0 = ax0.imshow(mp.wigner_function4(first_matrix, -x_bond2, x_bond2, q1, p1, 1).T, cmap='viridis', extent = extent1)
ax0.set_xlabel('X-quadrature')
ax0.set_ylabel('P-quadrature')
cbar1 = fig.colorbar(im0, ax=ax0)
    
# im2 = axes[1].imshow(mp.wigner_function4(second_matrix, -x_bond2, x_bond2, q2, p2, 1).T, cmap='viridis', extent = extent2)
# axes[1].set_xlabel('X-quadrature')
# axes[1].set_ylabel('P-quadrature')
# cbar2 = fig.colorbar(im2, ax=axes[1])

ax1 = fig.add_subplot(gs[1])
im1 = ax1.imshow(mp.wigner_function4(second_matrix, -x_bond3, x_bond3, q2, p2, 1).T, cmap='viridis', extent = extent2)
ax1.set_xlabel('X-quadrature')
ax1.set_ylabel('P-quadrature')
cbar2 = fig.colorbar(im1, ax=ax1)

cohn = mp.calculate_ph_num(first_matrix, n2, -x_bond2, step2)
vacn = mp.calculate_ph_num(second_matrix, n3, -x_bond3, step3)

text = fig.text(0.5, 0.95, f'Time: {0}', ha='center', fontsize=16)
#axes[0].set_title(f'Evolution of the pump state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
ax0.set_title(f'Evolution of the signal state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
#axes[1].set_title(f'Evolution of the signal state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')
ax1.set_title(f'Evolution of the loss state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')

f = IntProgress(min = 0, max = len(shorten_list_for_matrices))
percentage = HTML(value='0%')

count = 0

def update(num):
    global n1, n2, count, x1, x2, p1, p2, h, p_spep, x_right, x_left, step1_v1
    global x_bond1, x_bond2, x_bias, step1, step2, step3, ph_num1, ph_num2, ph_num3, delta_t
    length = len(shorten_list_for_matrices)
    
    # first_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[num], 0, n1)
    # second_matrix = mp.find_reduced_density_matrix(shorten_list_for_matrices[num], 1, n2)
    first_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[num], 1, n2, n1, n3, 0)
    second_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[num], 2, n3, n1, n2, 0)
    
    first_matrix = first_matrix / np.trace(first_matrix)
    second_matrix = second_matrix / np.trace(second_matrix)
    
    cohn = mp.calculate_ph_num(first_matrix, n2, -x_bond2, step2)
    vacn = mp.calculate_ph_num(second_matrix, n3, -x_bond3, step3)
    
    wg1 = mp.wigner_function4(first_matrix, -x_bond2, x_bond2, q1, p1, 1).T
    wg2 = mp.wigner_function4(second_matrix, -x_bond3, x_bond3, q2, p2, 1).T

    im0.set_data(wg1)
    im1.set_data(wg2)
    fig.canvas.draw_idle()  # Обновление отображения
    
    im0.set_clim(vmin=np.min(wg1), vmax=np.max(wg1))
    im1.set_clim(vmin=np.min(wg2), vmax=np.max(wg2))
    
    #axes[0].set_title(f'Evolution of the pump state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
    ax0.set_title(f'Evolution of the signal state \n Photon number in the state {np.round(cohn, 2)} \n Grid {2**(n1-nq1_red)} x {2**(n1-np1_red)}')
    #axes[1].set_title(f'Evolution of the signal state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')
    ax1.set_title(f'Evolution of the loss state \n Photons number in the state {np.round(vacn, 2)} \n Grid {2**(n2-nq2_red)} x {2**(n2-np2_red)}')
    
    text.set_text(f'Time: {np.round(count*delta_t, 2)}')
    count += 1
    f.value += 1
    percentage.value = f'{int((f.value / length) * 100)}%'  # обновляем процент выполнения
    return im0, im1

ani = animation.FuncAnimation(fig, update, frames=len(shorten_list_for_matrices), interval=250, blit=True)
plt.show()

# %%
f = IntProgress(min = 0, max = len(shorten_list_for_matrices))
display(f)
percentage = HTML(value='0%')
display(percentage)

ani.save('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/New_test_with_quality/Wigner_function_for_loss_process_-10_№2.gif', writer='pillow', fps=4)

# %%
# with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/New_test_with_quality/list_of_solutions_for_loss_-25.pkl', 'rb') as f:
#     solutions_with_losses = pickle.load(f)

# %%
shorten_list_for_matrices = []
saving_step = len(solutions_with_losses)//50
for i in range(0, len(solutions_with_losses), saving_step):
    shorten_list_for_matrices.append(solutions_with_losses[i])

# %% [markdown]
# ### Нахождение матриц плотности при работе с тремя модами

# %%
s = time.time()
first_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[-1], 1, n2, n1, n3, 0)
first_matrix = first_matrix/np.trace(first_matrix)
#second_matrix = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[-1], 2, n3, n1, n2, 0)
print(time.time()-s)

# %%
s = time.time()
first_matrix1 = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[0], 1, n2, n1, n3, 0)
first_matrix1 = first_matrix1/np.trace(first_matrix1)
#second_matrix1 = mp.find_reduced_density_matrix_for_3_modes(shorten_list_for_matrices[0], 2, n3, n1, n2, 0)
print(time.time()-s)

# %% [markdown]
# ### Вычисление и построение функций Вигнера при работе с тремя модами

# %%
nq1_red = 0
np1_red = 0
q = np.linspace(-10, 10, 2**(n1-nq1_red))
p = np.linspace(-30, 30, 2**(n1-np1_red))
plt.figure(figsize=(10,10))
#plt.imshow(first_matrix[300:724, 300:724])
plt.imshow(mp.wigner_function4(first_matrix, -x_bond2, x_bond2, q, p, 1).T, extent = [q[0], q[-1], p[0], p[-1]])
plt.colorbar()
plt.title("Wigner fuction of signal state")
plt.xlabel('X-quadrature')
plt.ylabel('P-quadrature')
print("Уровень потерь:" ,np.round((mp.calculate_ph_num(first_matrix1, n2, -x_bond2, step2)-mp.calculate_ph_num(first_matrix, n2, -x_bond2, step2))/mp.calculate_ph_num(first_matrix1, n2, -x_bond2, step2), 2))
print("Количество энергии в моде:" ,np.round(mp.calculate_ph_num(first_matrix, n2, -x_bond2, step2), 1))
plt.show()

# %%
plt.figure(figsize=(10,10))
#plt.imshow(first_matrix1[300:724, 300:724])
plt.title("Wigner fuction of signal state")
nq1_red = 0
np1_red = 0
q = np.linspace(-10, 10, 2**(n1-nq1_red))
p = np.linspace(-30, 30, 2**(n1-np1_red))
plt.imshow(mp.wigner_function4(first_matrix1, -x_bond2, x_bond2, q, p, 1).T, extent = [q[0], q[-1], p[0], p[-1]])
plt.colorbar()
plt.xlabel('X-quadrature')
plt.ylabel('P-quadrature')
print("Уровень потерь:" ,(mp.calculate_ph_num(first_matrix1, n2, -x_bond2, step2)-mp.calculate_ph_num(first_matrix1, n2, -x_bond2, step2))/mp.calculate_ph_num(first_matrix1, n2, -x_bond2, step2))
print("Количество энергии в моде:" ,np.round(mp.calculate_ph_num(first_matrix1, n2, -x_bond2, step2), 1))
plt.show()

# %% [markdown]
# ## Сравнение эволюции в фоковском базисе и в непрерывном с т.с.

# %%
with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/Data_for_article/alpha_20_comparison/solutions_for_Fock_basis_alpha_10_photon_dynamics_#3_100000_steps.pkl', 'rb') as f:
    photon_dynamics_general = pickle.load(f)

# %%
fock_basis_ph_d = []
for i in range(0,len(photon_dynamics_general[0]),10):
    fock_basis_ph_d.append(photon_dynamics_general[0][i])

fock_basis_ph_d_2 = []
for i in range(0,len(photon_dynamics_general[0]),10):
    fock_basis_ph_d_2.append(photon_dynamics_general[1][i])

fock_basis_ph_d_3 = []
for i in range(0,len(fock_basis_ph_d_2),1):
    fock_basis_ph_d_3.append(2*fock_basis_ph_d_2[i]+fock_basis_ph_d[i])

# %%
plt.figure(figsize = (13,8))
plt.grid(alpha=0.5)
#plt.title("Динамика числа фотонов в модах сигнала и накачки в ходе эволюции \n под действием гамильтониана вырожденного спонтанного параметрического рассеяния (SPDC), \n вычисленной в непрерывном представлении с помощью тензорных сетей и в Фоковском базисе")
plt.xlabel("Время, условные единицы", fontsize = 14)
plt.ylabel("Количество фотонов в модах", fontsize = 14)
plt.plot(np.arange(len(photon_number_dynamics[0][:-1]))*0.002, np.array(photon_number_dynamics[0][:-1]), label = "Мода накачки (непрерывное предст. + тензорные сети)")
plt.plot(np.arange(len(photon_number_dynamics[0][:-1]))*0.002, photon_number_dynamics[1][:-1], label = "Мода сигнала (непрерывное предст. + тензорные сети)")
plt.plot(np.arange(len(photon_number_dynamics[0][:-1]))*0.002, 2*np.array(photon_number_dynamics[0][:-1]) + np.array(photon_number_dynamics[1][:-1])-1.2, label = "Общая энергия мод (непрерывное предст. + тензорные сети)")
plt.plot(np.arange(len(fock_basis_ph_d))*0.02, fock_basis_ph_d, "g+", label = "Мода сигнала (Фококвский базис)")
plt.plot(np.arange(len(fock_basis_ph_d_2))*0.02, fock_basis_ph_d_2, "r+", label = "Мода накачки (Фококвский базис)")
plt.plot(np.arange(len(fock_basis_ph_d_3))*0.02, fock_basis_ph_d_3, "bo", label = "Общая энергия мод (Фококвский базис)", )
#plt.plot(np.arange(len(photon_dynamics_general[0]))*0.002, 200*np.ones(len(photon_dynamics_general[0])))
plt.xlim(0,0.83)
plt.ylim(-5,280)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.legend()
#plt.savefig('photon_d_for_thesis_2.png', bbox_inches='tight')
plt.show()

# %%
# with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/Data_for_article/alpha_20_comparison/rho_matrices_ph_basis_4.pkl', 'rb') as f:
#     rho_matrices_hp_basis = pickle.load(f)

# %%
num_iter = 30
rho_1_tn = np.array(matrices[num_iter]/np.max(np.array(matrices[num_iter])))
rho_ph_b = np.array(rho_matrices_hp_basis[num_iter]/np.max(np.array(rho_matrices_hp_basis[num_iter])))

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (12,6))
im1 = ax1.imshow(np.real(rho_1_tn))
im2 = ax2.imshow(np.real(rho_ph_b))
#plt.title("Матрица плотности сигнала, вычисленная двумя способами и представленная в непрерывном представлении")
ax1.text(1.35, 1.27, f'Матрица плотности моды сигнала в ходе эволюции под дейсвтием гамильтониана SPDC, \n вычисленная двумя разными методами и представленная в непрерывном представлении', transform=ax1.transAxes, ha='center')
ax1.text(0.5, 1.05, f'Матрица плотности моды сигнала, \n вычисленная в координатном представлении \n с помощью тензорных сетей', transform=ax1.transAxes, ha='center')
ax1.text(0.1, 0.9, f't={num_iter}', color = 'white', transform=ax1.transAxes, ha='center')
ax2.text(0.5, 1.05, f'Матрица плотности моды сигнала, \n вычисленная в Фоковском базисе \n и переведенная в координатное представление', transform=ax2.transAxes, ha='center')
ax2.text(0.1, 0.9, f't={num_iter}', color = 'white', transform=ax2.transAxes, ha='center')
fig.colorbar(im1, ax=ax1)
fig.colorbar(im2, ax=ax2)
plt.show()
np.linalg.norm(rho_1_tn, ord='fro')
# Out:
# 3.630868747011774

# %% [markdown]
# ## Перевод матрицы плотности из непрерывного базиса в Фоковский

# %%
n1 = 12
n2 = 13

# %%
with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/Data_for_article/alpha_20_comparison/list_of_solutions_with_tn_incr_n1n2_1e-3.pkl', 'rb') as f:
    set_of_solutions = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/Data_for_article/alpha_20_comparison/list_of_solutions_with_tn_incr_n1n2_1e-3.pkl', 'rb') as f:
#       2     set_of_solutions = pickle.load(f)
#
# File ~\miniconda3\envs\matrpr\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/Data_for_article/alpha_20_comparison/list_of_solutions_with_tn_incr_n1n2_1e-3.pkl'

# %%
with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/Data_for_article/high_amplitude/list_of_solutions_with_tn_alpha_100_the_last_extended.pkl', 'rb') as f:
    set_of_solutions_high_amplitude = pickle.load(f)

# %%
number_of_elements = []
for mps in set_of_solutions:
    number_of_elements.append(mp.calculate_number_of_elements_in_MPS(mps))

# %%
number_of_elements_ha = []
for mps in set_of_solutions_high_amplitude:
    number_of_elements_ha.append(mp.calculate_number_of_elements_in_MPS(mps))

# %%
plt.figure(figsize = (8,5))
plt.plot(np.linspace(0, 1, len(number_of_elements)), np.log10(2**25/np.array(number_of_elements)), label = r'Case when pump is initialized in $|\alpha\rangle=|10\rangle$')
plt.plot(0.001*np.arange(len(number_of_elements_ha)), np.log10(2**30/np.array(number_of_elements_ha)), label = r'Case when pump is initialized in $|\alpha\rangle=|100\rangle$')
#plt.yscale('log')
plt.xlabel("Time, arbitrary units", fontsize = 16)
plt.ylabel(r"$Log_{10}$(Compression Ratio)", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.grid(alpha=0.3)
plt.xlim(0,1.01)
#plt.ylim(0,10000)
plt.legend()
#plt.savefig('compression_ratio.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Нахождение MPS для волновых функций Фоковских состояний

# %% [markdown]
# #### Необходимые функции для нахождения Фоковских состояний

# %%
def hermit_pol_3_comb(n, x):
    if n == 0:
        return 1 * np.exp(- x**2 / 2)
    elif n == 1:
        return 2 * x * np.exp(- x**2 / 2)

    h0 = 1
    h1 = 2 * x
    for i in range(2, n + 1):
        h = (2 * x * h1 - 2 * (i - 1) * h0)*(np.exp(- x**2 / 2))**(1/(n-1))
        h1 = h1 * (np.exp(- x**2 / 2))**(1/(n-1))
        h0, h1 = h1, h

    return h1

# %%
def psi_fock_3(n, x):
    # Calculate the logarithm of the factorial
    log_factorial_n = sum(np.log(np.arange(1, n + 1)))

    # Calculate the logarithm of the normalization factor
    log_norm = 0.5 * (n * np.log(2) + log_factorial_n + 0.5 * np.log(np.pi))

    # Calculate the Hermite polynomial
    hermite_value = hermit_pol_3_comb(n, x)

    # Combine the results
    result = hermite_value / np.exp(log_norm)

    return result

# %% [markdown]
# #### Вычисление волновых функций Фоковских состояний

# %%
fock_states = []
for i in tqdm(range(0,250)):
    fock_states.append(psi_fock_3(i, np.linspace(-10*np.sqrt(2)-10, 10*np.sqrt(2)+15, 2**12)))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 250/250 [00:09<00:00, 25.46it/s]

# %% [markdown]
# #### Нахождение MPS для волновых функций Фоковских состояний

# %%
fock_states_mps = []
for i in tqdm(range(0,250)):
    fock_states_mps.append(mp.vec_to_mps(fock_states[i], 1e-6))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 250/250 [00:00<00:00, 451.98it/s]

# %% [markdown]
# #### Вычисление MPO для матрицы плотности состояний

# %%
with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/2025-07-30_17-05-01/solutions.pkl', 'rb') as f:
    set_of_solutions = pickle.load(f)

# %%
len(set_of_solutions), len(set_of_solutions[0])
# Out:
# (901, 25)

# %%
column_matrix = np.vstack(fock_states).T
row_matrix = np.vstack(fock_states)

# %%
computed_matrices_signal = []
for k in tqdm(range(0, len(set_of_solutions), 20)):
    density_matrix = mp.find_reduced_density_matrix2(set_of_solutions[k], 1, n2, 0)
    density_matrix = density_matrix / np.trace(density_matrix)
    fock_basis_matrix = row_matrix @ density_matrix @ column_matrix
    computed_matrices_signal.append(fock_basis_matrix)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 46/46 [03:27<00:00,  4.51s/it]

# %%
with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/2025-07-30_17-05-01/density_matrices_converted_to_Fb_signal.pkl', 'wb') as f:
    pickle.dump(computed_matrices_signal, f)

# %%
computed_matrices_pump = []
for k in tqdm(range(0, len(set_of_solutions), 20)):
    density_matrix = mp.find_reduced_density_matrix2(set_of_solutions[k], 0, n1, 0)
    density_matrix = density_matrix / np.trace(density_matrix)
    fock_basis_matrix = row_matrix @ density_matrix @ column_matrix
    computed_matrices_pump.append(fock_basis_matrix)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 46/46 [01:11<00:00,  1.56s/it]

# %%
with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/2025-07-30_17-05-01/density_matrices_converted_to_Fb_pump.pkl', 'wb') as f:
    pickle.dump(computed_matrices_pump, f)

# %%
plt.imshow(computed_matrices_pump[10])
plt.show()

# %%
def create_dm_mpo_from_mps(mps):
    dm_mpo = []
    for i in range(len(mps)):
        tensor_combination = oe.contract("ijk, abc -> iajbkc", mps[i], np.conj(mps[i]), optimize = True)
        shape = tensor_combination.shape
        dm_mpo.append(tensor_combination.reshape(shape[0]*shape[1], shape[2], shape[3], shape[4]*shape[5]))
    return dm_mpo

# %%
def contract_mpo_and_two_mps(mps1, mps2, mpo, output = 'tensor'):
    mps_one = mps1.copy()
    mps_two = mps2.copy()
    mpo_use = mpo.copy()

    begin = mps_one[0].shape[0] * mps_two[0].shape[0] * mpo_use[0].shape[0]
    end = mps_one[-1].shape[-1] * mps_two[-1].shape[-1] * mpo_use[-1].shape[-1]

    result = np.array(1).reshape(1,1,1)
    if begin <= end:
        for i in range(len(mps1)):
            result = oe.contract("abc, ajk, bjgh, cgm -> khm", result, mps_one[i], mpo_use[i], mps_two[i], optimize = True)
    else:
        for i in range(len(mps1)):
            result = oe.contract("abc, ija, gjhb, phc -> igp", result, mps_one[-i-1], mpo_use[-i-1], mps_two[-i-1], optimize = True)
    if output == 'tensor':
        return result
    else:
        return result[0][0][0]

# %%
def contract_two_mps(mps1, mps2, output = "tensor"):
    mps_one = mps1.copy()
    mps_two = mps2.copy()

    begin = mps_one[0].shape[0] * mps_two[0].shape[0]
    end = mps_one[-1].shape[-1] * mps_two[-1].shape[-1]

    result = np.array(1).reshape(1,1)
    if begin <= end:
        for i in range(len(mps1)):
            result = oe.contract("ia, ijk, ajc -> kc", result, mps_one[i], mps_two[i], optimize = True)
    else:
        for i in range(len(mps1)):
            result = oe.contract("kc, ijk, ajc -> ia", result, mps_one[-i-1], mps_two[-i-1], optimize = True)
    if output == 'tensor':
        return result
    else:
        return result[0][0]

# %%
step_number = 200

# %%
final_density_matrices = []
for k in tqdm(range(0, len(set_of_solutions), 40)):
    environment = contract_two_mps(set_of_solutions[k][:n1], set_of_solutions[k][:n1])
    environment = environment.reshape(-1)
    density_matrix_mpo = create_dm_mpo_from_mps(set_of_solutions[k][n1:])
    final_density_matrix_mpo = density_matrix_mpo.copy()
    final_density_matrix_mpo[0] = np.einsum('i, ijkl -> jkl', environment, density_matrix_mpo[0])
    shape = final_density_matrix_mpo[0].shape
    final_density_matrix_mpo[0] = final_density_matrix_mpo[0].reshape(1, shape[0], shape[1], shape[2])
    length = 200
    dm_in_ph_basis = np.zeros((length,length), dtype = complex)
    for i in range(length):
        for j in range(length):
            second_move = contract_mpo_and_two_mps(fock_states_mps[i], fock_states_mps[j], final_density_matrix_mpo, output = 'number')
            dm_in_ph_basis[i,j] = second_move
    final_density_matrices.append(dm_in_ph_basis)
    #with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/transformaton_cv_density_m_to_FB/density_matrices_converted_to_Fb_№41.pkl', 'wb') as f:
        #pickle.dump(final_density_matrices, f)
# Out:
#   0%|                                                                                           | 0/21 [00:22<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 14
#      12 for i in range(length):
#      13     for j in range(length):
# ---> 14         second_move = contract_mpo_and_two_mps(fock_states_mps[i], fock_states_mps[j], final_density_matrix_mpo, output = 'number')
#      15         dm_in_ph_basis[i,j] = second_move
#      16 final_density_matrices.append(dm_in_ph_basis)
#
# Cell In[12], line 12, in contract_mpo_and_two_mps(mps1, mps2, mpo, output)
#      10 if begin <= end:
#      11     for i in range(len(mps1)):
# ---> 12         result = oe.contract("abc, ajk, bjgh, cgm -> khm", result, mps_one[i], mpo_use[i], mps_two[i], optimize = True)
#      13 else:
#      14     for i in range(len(mps1)):
#
# File ~\miniconda3\envs\matrpr\Lib\site-packages\opt_einsum\contract.py:603, in contract(subscripts, out, use_blas, optimize, memory_limit, backend, *operands, **kwargs)
#     600 if gen_expression:
#     601     return ContractExpression(full_str, contraction_list, constants_dict, **kwargs)
# --> 603 return _core_contract(operands, contraction_list, backend=backend, out=out, **kwargs)
#
# File ~\miniconda3\envs\matrpr\Lib\site-packages\opt_einsum\contract.py:687, in _core_contract(operands_, contraction_list, backend, evaluate_constants, out, **kwargs)
#     684     axes = ((), ())
#     686 # Contract!
# --> 687 new_view = _tensordot(*tmp_operands, axes=axes, backend=backend, **kwargs)
#     689 # Build a new view if needed
#     690 if (tensor_result != results_index) or handle_out:
#
# File ~\miniconda3\envs\matrpr\Lib\site-packages\opt_einsum\sharing.py:140, in tensordot_cache_wrap.<locals>.cached_tensordot(x, y, axes, backend)
#     137 @functools.wraps(tensordot)
#     138 def cached_tensordot(x, y, axes=2, backend="numpy"):
#     139     if not currently_sharing():
# --> 140         return tensordot(x, y, axes, backend=backend)
#     142     # hash based on the (axes_x,axes_y) form of axes
#     143     _save_tensors(x, y)
#
# File ~\miniconda3\envs\matrpr\Lib\site-packages\opt_einsum\contract.py:470, in _tensordot(x, y, axes, backend)
#     468 """Base tensordot."""
#     469 fn = backends.get_func("tensordot", backend)
# --> 470 return fn(x, y, axes=axes)
#
# File ~\miniconda3\envs\matrpr\Lib\site-packages\numpy\core\numeric.py:1121, in tensordot(a, b, axes)
#    1119 at = a.transpose(newaxes_a).reshape(newshape_a)
#    1120 bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> 1121 res = dot(at, bt)
#    1122 return res.reshape(olda + oldb)
#
# KeyboardInterrupt:

# %%
start_time = time.time()
value = mp.mpo_to_matrix(final_density_matrix_mpo) @ fock_states[0] @ fock_states[0]
print(time.time() - start_time)
# Out:
# 1.4677600860595703

# %%
matrix = mp.mpo_to_matrix(final_density_matrix_mpo)

# %%
print(asizeof.asizeof(matrix)/2**20, "Мегабайт")
# Out:
# 1024.000259399414 Мегабайт

# %%
print(asizeof.asizeof(fock_states[0])/2**20, "Мегабайт")
# Out:
# 0.0626373291015625 Мегабайт

# %%
column_matrix = np.vstack(fock_states).T
row_matrix = np.vstack(fock_states)

# %%
computed_matrices_signal = []
for k in tqdm(range(0, len(set_of_solutions), 40)):
    environment = contract_two_mps(set_of_solutions[k][:n1], set_of_solutions[k][:n1])
    environment = environment.reshape(-1)
    density_matrix_mpo = create_dm_mpo_from_mps(set_of_solutions[k][n1:])
    final_density_matrix_mpo = density_matrix_mpo.copy()
    final_density_matrix_mpo[0] = np.einsum('i, ijkl -> jkl', environment, density_matrix_mpo[0])
    shape = final_density_matrix_mpo[0].shape
    final_density_matrix_mpo[0] = final_density_matrix_mpo[0].reshape(1, shape[0], shape[1], shape[2])
    matrix = mp.mpo_to_matrix(final_density_matrix_mpo)
    fock_basis_matrix = row_matrix @ matrix @ column_matrix
    computed_matrices_signal.append(fock_basis_matrix)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:35<00:00,  1.69s/it]

# %%
computed_matrices_pump = []
for k in tqdm(range(0, len(set_of_solutions), 40)):
    environment = contract_two_mps(set_of_solutions[k][n1:], set_of_solutions[k][n1:])
    environment = environment.reshape(-1)
    density_matrix_mpo = create_dm_mpo_from_mps(set_of_solutions[k][:n1])
    final_density_matrix_mpo = density_matrix_mpo.copy()
    final_density_matrix_mpo[-1] = np.einsum('l, ijkl -> ijk', environment, density_matrix_mpo[-1])
    shape = final_density_matrix_mpo[-1].shape
    final_density_matrix_mpo[-1] = final_density_matrix_mpo[-1].reshape(shape[0], shape[1], shape[2], 1)
    matrix = mp.mpo_to_matrix(final_density_matrix_mpo)
    fock_basis_matrix = row_matrix @ matrix @ column_matrix
    computed_matrices_pump.append(fock_basis_matrix)
# Out:
#  62%|██████████████████████████████████████████████████▏                              | 13/21 [36:15<22:18, 167.37s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[143], line 10
#       8 shape = final_density_matrix_mpo[-1].shape
#       9 final_density_matrix_mpo[-1] = final_density_matrix_mpo[-1].reshape(shape[0], shape[1], shape[2], 1)
# ---> 10 matrix = mp.mpo_to_matrix(final_density_matrix_mpo)
#      11 fock_basis_matrix = row_matrix @ matrix @ column_matrix
#      12 computed_matrices_pump.append(fock_basis_matrix)
#
# File ~\Desktop\MPS_directory\TensorNetworks\MatrixProductFunctions.py:238, in mpo_to_matrix(mpo)
#     236 mul = mpo[0]
#     237 for i in range(1, len(mpo)):
# --> 238     mul = np.tensordot(mul, mpo[i], axes = 1)
#     239 mul = mul.reshape(2 * np.ones(2 * len(mpo), dtype = int))
#     240 sh_t = np.arange(0, 2 * len(mpo), 2)
#
# File ~\miniconda3\envs\matrpr\Lib\site-packages\numpy\core\numeric.py:1121, in tensordot(a, b, axes)
#    1119 at = a.transpose(newaxes_a).reshape(newshape_a)
#    1120 bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> 1121 res = dot(at, bt)
#    1122 return res.reshape(olda + oldb)
#
# KeyboardInterrupt:

# %%
environment = contract_two_mps(set_of_solutions[1][n1:], set_of_solutions[1][n1:])
environment = environment.reshape(-1)
environment.shape
# Out:
# (4,)

# %%
density_matrix_mpo = create_dm_mpo_from_mps(set_of_solutions[1][:n1])
for i in density_matrix_mpo:
    print(i.shape)
# Out:
# (1, 2, 2, 1)
# (1, 2, 2, 4)
# (4, 2, 2, 9)
# (9, 2, 2, 16)
# (16, 2, 2, 36)
# (36, 2, 2, 49)
# (49, 2, 2, 49)
# (49, 2, 2, 25)
# (25, 2, 2, 16)
# (16, 2, 2, 16)
# (16, 2, 2, 9)
# (9, 2, 2, 4)

# %%
final_density_matrix_mpo = density_matrix_mpo.copy()
final_density_matrix_mpo[-1] = np.einsum('l, ijkl -> ijk', environment, density_matrix_mpo[-1])
for i in final_density_matrix_mpo:
    print(i.shape)
# Out:
# (1, 2, 2, 1)
# (1, 2, 2, 4)
# (4, 2, 2, 9)
# (9, 2, 2, 16)
# (16, 2, 2, 36)
# (36, 2, 2, 49)
# (49, 2, 2, 49)
# (49, 2, 2, 25)
# (25, 2, 2, 16)
# (16, 2, 2, 16)
# (16, 2, 2, 9)
# (9, 2, 2)

# %%
shape = final_density_matrix_mpo[-1].shape
final_density_matrix_mpo[-1] = final_density_matrix_mpo[-1].reshape(shape[0], shape[1], shape[2], 1)

# %%
for i in final_density_matrix_mpo:
    print(i.shape)
# Out:
# (1, 2, 2, 1)
# (1, 2, 2, 4)
# (4, 2, 2, 9)
# (9, 2, 2, 16)
# (16, 2, 2, 36)
# (36, 2, 2, 36)
# (36, 2, 2, 25)
# (25, 2, 2, 16)
# (16, 2, 2, 16)
# (16, 2, 2, 9)
# (9, 2, 2, 4)
# (4, 2, 2, 1)

# %%
plt.imshow(computed_matrices_signal[10][:250, :250])
plt.colorbar()
plt.show()

# %%
final_density_matrices = []
for k in tqdm(range(0, len(set_of_solutions), 40)):
    environment = contract_two_mps(set_of_solutions[k][n1:], set_of_solutions[k][n1:])
    environment = environment.reshape(-1)
    density_matrix_mpo = create_dm_mpo_from_mps(set_of_solutions[k][:n1])
    final_density_matrix_mpo = density_matrix_mpo.copy()
    final_density_matrix_mpo[-1] = np.einsum('l, ijkl -> ijk', environment, density_matrix_mpo[-1])
    shape = final_density_matrix_mpo[-1].shape
    final_density_matrix_mpo[-1] = final_density_matrix_mpo[-1].reshape(shape[0], shape[1], shape[2], 1)
    length = 200
    dm_in_ph_basis = np.zeros((length,length), dtype = complex)
    for i in range(length):
        for j in range(length):
            second_move = contract_mpo_and_two_mps(fock_states_mps[i], fock_states_mps[j], final_density_matrix_mpo, output = 'number')
            dm_in_ph_basis[i,j] = second_move
    final_density_matrices.append(dm_in_ph_basis)
    #with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/transformaton_cv_density_m_to_FB/density_matrices_converted_to_Fb_№31.pkl', 'wb') as f:
        pickle.dump(final_density_matrices, f)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 21/21 [19:17:10<00:00, 3306.22s/it]

# %%
# with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/Data_for_article/alpha_20_comparison/density_matrices_converted_to_Fb.pkl', 'wb') as f:
#     pickle.dump(final_density_matrices, f)

# %%
len(final_density_matrices)

# %%
plt.imshow(final_density_matrices[10].real)
plt.colorbar()
plt.show()

# %%
with open('C:/Users/kaprn/Desktop/MPS_directory/TensorNetworks/Tests_of_spdc/Data_for_article/alpha_20_comparison/Selected_for_article/solutions_for_Fock_basis_alpha_10_#3_100000_steps.pkl', 'rb') as f:
    density_matrices_in_Fb = pickle.load(f)

# %%
density_matrices_initially_in_Fb = []
for i in range(0, len(density_matrices_in_Fb), 20):
    dm_Fb = density_matrices_in_Fb[i].reshape(300, 300)
    sol_U, sol_S, sol_V = np.linalg.svd(dm_Fb, full_matrices=False)
    density_matrix_one_fp = sol_U @ np.diag(sol_S) 
    density_matrix_one = density_matrix_one_fp @ np.conj(density_matrix_one_fp.T)
    
    density_matrix_two_fp = (np.diag(sol_S) @ sol_V).T 
    density_matrix_two = density_matrix_two_fp @ np.conj(density_matrix_two_fp.T)

    density_matrices_initially_in_Fb.append(density_matrix_two[:250, :250].real)

# %%
len(density_matrices_initially_in_Fb)
# Out:
# 26

# %%
plt.imshow(density_matrices_initially_in_Fb[40])
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 plt.imshow(density_matrices_initially_in_Fb[40])
#       2 plt.colorbar()
#       3 plt.show()
#
# IndexError: list index out of range

# %%
def compute_fidelity(rho1, rho2):
    return (np.trace(sqrtm(sqrtm(rho1)@rho2@sqrtm(rho1))))**2

# %%
fidelity_storage_pump = []
for i in range(min(len(density_matrices_initially_in_Fb), len(computed_matrices_pump))):
    fidelity_storage_pump.append(compute_fidelity(density_matrices_initially_in_Fb[i]/np.trace(density_matrices_initially_in_Fb[i]), computed_matrices_pump[i]/np.trace(computed_matrices_pump[i])))

# %%
plt.plot(fidelity_storage)
plt.plot(fidelity_storage_pump)
plt.show()

# %%
plt.imshow(density_matrices_initially_in_Fb[80][:20, :20]/density_matrices_initially_in_Fb[80][0,0])
plt.colorbar()
plt.show()

# %%
plt.imshow(final_density_matrices[80].real[:20, :20]/final_density_matrices[80].real[0,0]-density_matrices_initially_in_Fb[80][:20, :20]/density_matrices_initially_in_Fb[80][0,0])
plt.colorbar()
plt.show()

# %%
compute_fidelity(density_matrices_initially_in_Fb[80][:20, :20]/np.trace(density_matrices_initially_in_Fb[80]), final_density_matrices[80].real[:20, :20]/np.trace(final_density_matrices[80].real))
# Out:
# (0.8149621255038509+2.860743871502663e-10j)

# %%
def calculate_dm_in_ph_basis(mpo, fock_states_mps, length):
    matrix_one = [[1 * i] * length for i in range(length)]
    matrix_two = [[1 * i for i in range(length)]] * length
    @njit
    def calculate_dm_element_in_ph_basis(i,j):
        first_move = mp.mpo_x_mps(mpo, fock_states_mps[i])
        second_move = mp.mps_scalar_multiplication(first_move, fock_states_mps[j])
        return second_move
    vectorized_function = np.vectorize(calculate_dm_element_in_ph_basis)
    W = vectorized_function(matrix_one, matrix_two)
    return W.real

# %%
n_step = 350
reddm1 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 0, n1, 0)
reddm2 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 1, n2, 0)
reddm1 = reddm1 / np.trace(reddm1)
reddm2 = reddm2 / np.trace(reddm2)
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (13,6))
im1 = ax1.imshow(reddm1)
im2 = ax2.imshow(reddm2)
plt.show()

# %%
plt.plot(reddm2[4096])
plt.show()

# %%
n_step = 400
reddm1 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 0, n1, 0)
reddm2 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 1, n2, 0)
reddm1 = reddm1 / np.trace(reddm1)
reddm2 = reddm2 / np.trace(reddm2)
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (13,6))
im1 = ax1.imshow(reddm1)
im2 = ax2.imshow(reddm2)
plt.show()

# %%
plt.plot(reddm2[4096])
plt.show()

# %%
n_step = 460
reddm1 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 0, n1, 0)
reddm2 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 1, n2, 0)
reddm1 = reddm1 / np.trace(reddm1)
reddm2 = reddm2 / np.trace(reddm2)
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (13,6))
im1 = ax1.imshow(reddm1)
im2 = ax2.imshow(reddm2)
plt.show()

# %%
plt.plot(reddm2[4096])
plt.show()

# %%
n_step = 500
reddm1 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 0, n1, 0)
reddm2 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 1, n2, 0)
reddm1 = reddm1 / np.trace(reddm1)
reddm2 = reddm2 / np.trace(reddm2)
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (13,6))
im1 = ax1.imshow(reddm1)
im2 = ax2.imshow(reddm2)
plt.show()

# %%
plt.plot(reddm2[4096])
plt.show()

# %%
n_step = 550
reddm1 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 0, n1, 0)
reddm2 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 1, n2, 0)
reddm1 = reddm1 / np.trace(reddm1)
reddm2 = reddm2 / np.trace(reddm2)
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (13,6))
im1 = ax1.imshow(reddm1)
im2 = ax2.imshow(reddm2)
plt.show()

# %%
plt.plot(reddm2[4096])
plt.show()

# %%
n_step = 600
reddm1 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 0, n1, 0)
reddm2 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 1, n2, 0)
reddm1 = reddm1 / np.trace(reddm1)
reddm2 = reddm2 / np.trace(reddm2)
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (13,6))
im1 = ax1.imshow(reddm1)
im2 = ax2.imshow(reddm2)
plt.show()

# %%
plt.plot(reddm2[4096])
plt.show()

# %%
n_step = -1
reddm1 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 0, n1, 0)
reddm2 = mp.find_reduced_density_matrix2(set_of_solutions[n_step], 1, n2, 0)
reddm1 = reddm1 / np.trace(reddm1)
reddm2 = reddm2 / np.trace(reddm2)
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (13,6))
im1 = ax1.imshow(reddm1)
im2 = ax2.imshow(reddm2)
plt.show()

# %%
plt.plot(reddm2[4096])
plt.show()

# %%
colors = ["#D4A373", "#A98467", "#6C584C", "#ADC178", "#F0EAD2"]
plt.figure(figsize=(8, 2))
plt.title("Тёплая осенняя гамма")
for i, color in enumerate(colors):
    plt.fill_between([i-0.5, i+0.5], -0.5, 0.5, color=color)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ## Моделирование спонтанного параметрического рассеяния (SPDC) с учётом потерь

# %% [markdown]
# ### Гамильтониан SPDC с потерями:

# %% [markdown]
# \begin{equation*}
# \begin{split}
# & \hat{H} = \hat{H}_{spdc} + \hat{H}_{loss} = i\hbar \chi^{(2)}(\hat{a}_{pump}^{\dagger}\hat{a}_{sig}\hat{a}_{sig} - \hat{a}_{pump}\hat{a}_{sig}^{\dagger}\hat{a}_{sig}^{\dagger}) + \dfrac{\theta}{2i}((\hat{a}^\dagger_{pump} + \hat{a}^\dagger_{sig}) \hat{a}_{loss} - \hat{a}_{loss}^\dagger (\hat{a}_{pump} + \hat{a}_{sig})) = \\
# & = -i\dfrac{\hbar \chi^{(2)}}{\sqrt{2}}(\dfrac{d}{dx_{pump}}(\hat{x}_{sig}^2 + \dfrac{d^2}{dx_{sig}^2}) - \hat{x}_{pump}(\hat{1}_{sig} + 2\hat{x}_{sig}\dfrac{d}{dx_{sig}})) - \dfrac{i\theta}{2}((\hat{x}_{pump} + \hat{x}_{sig})\dfrac{d}{dx_{loss}} - \hat{x}_{loss}(\dfrac{d}{dx_{pump}} + \dfrac{d}{dx_{sig}}))
# \end{split}
# \end{equation*}

# %%
chi = 1 / 2
theta = 1
delta_t = 0.001 / 5

x_bond1 = 10
x_bond2 = 5
x_bond3 = 5
n1 = 8
n2 = 8
n3 = 8
x_bias = 20 * 5
step1 = x_bond1 / 2**(n1 - 1)
step2 = x_bond2 / 2**(n2 - 1)
step3 = x_bond3 / 2**(n3 - 1)

# %% [markdown]
# #### Первая и вторая часть MPO для моды накачки: $\dfrac{d}{dx_{pump}}$ и $-\hat{x}_{pump}$

# %%
coh_operartor_one = mp.der_mpo(n1, step1)
coh_operator_two = mp.mpo_mul_num(mp.x_mpo(n1, x_bias - x_bond1, step1), -1)
len(coh_operartor_one), len(coh_operator_two)

# %% [markdown]
# #### Первая и вторая часть MPO для вакуумного состояния: $\hat{x}_{sig}^2 + \dfrac{d^2}{dx_{sig}^2}$ и $\hat{1}_{sig} + 2\hat{x}_{sig}\dfrac{d}{dx_{sig}}$

# %%
vac_operator_one = mp.mpo_sum(mp.mpo_multiplication(mp.x_mpo(n2, - x_bond2, step2), mp.x_mpo(n2, - x_bond2, step2)), mp.der2_mpo(n2, step2))
vac_operator_two = mp.mpo_sum(mp.one_mpo(n2), mp.mpo_mul_num(mp.mpo_multiplication(mp.x_mpo(n2, - x_bond2, step2), mp.der_mpo(n2, step2)), 2))

# %% [markdown]
# #### Склейка mpo для когернетного состояния и вакуумного состояния

# %%
first_part = coh_operartor_one + vac_operator_one
second_part = coh_operator_two + vac_operator_two

# %% [markdown]
# #### Получение полного гамильтониана SPDC

# %%
common_operator = mp.mpo_mul_num(mp.mpo_sum(first_part, second_part), chi / (np.sqrt(2)))

# %% [markdown]
# #### Гамильтониан потерь (модель светоделителя)

# %% [markdown]
# $- \dfrac{i\theta}{2}((\hat{x}_{pump} + \hat{x}_{sig})\dfrac{d}{dx_{loss}} - \hat{x}_{loss}(\dfrac{d}{dx_{pump}} + \dfrac{d}{dx_{sig}}))$

# %%
p1 = mp.x_mpo(n1, x_bias - x_bond1, step1) + mp.one_mpo(n2) + mp.der_mpo(n3, step3)
p2 = mp.one_mpo(n1) + mp.x_mpo(n2, - x_bond2, step2) + mp.der_mpo(n3, step3)
p3 = mp.der_mpo(n1, step1) + mp.one_mpo(n2) + mp.x_mpo(n3, - x_bond3, step3)
p4 = mp.one_mpo(n1) + mp.der_mpo(n2, step2) + mp.x_mpo(n3, - x_bond3, step3)

p_un1 = mp.mpo_sum(p1, p2)
p_un2 = mp.mpo_mul_num(mp.mpo_sum(p3, p4), -1)
p_unsum = mp.mpo_sum(p_un1, p_un2)

p_final = mp.mpo_mul_num(p_unsum, -theta * 1j/2)

# %%
final_mpo = mp.mpo_sum(mp.one_mpo(n1 + n2), mp.mpo_mul_num(common_operator, delta_t))

# %%
def cut_mps(mps, n):
    n_free = n - 1
    tensor_product = mps[-1]
    first_part = mps[0][:,0,:]
    second_part = mps[0][:,1,:]
    for i in range(n_free-1):
        tensor_product = np.einsum("abc, cdf -> abdf", mps[-2-i], tensor_product)
        tensor_product = tensor_product.reshape(tensor_product.shape[0], tensor_product.shape[1]*tensor_product.shape[2], tensor_product.shape[3])
    for i in range(1, len(mps)-n+1):
        first_part = first_part @ mps[i][:,1,:]
        second_part = second_part @ mps[i][:,0,:]
    if n > 1:
        return np.concatenate((np.einsum("ab, bcd -> acd", first_part, tensor_product).reshape(-1), np.einsum("ab, bcd -> acd", second_part, tensor_product).reshape(-1)))
    else:
        return np.array((first_part, second_part)).reshape(-1)
